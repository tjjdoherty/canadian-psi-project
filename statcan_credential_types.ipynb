# %% [markdown]
# # StatCan Data on Credential type across institutions from 2011-2021
#
# As Canadian PSIs have declined in domestic enrolment and replaced this with international students, has their credential offering changed as a result?

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading in the CSV
df = pd.read_csv("/Users/thomasdoherty/Desktop/canadian-psi-project/psi_data/statcan_data/statcan-credentials.csv", encoding='utf-8')

# %%
df
# Out:
#         REF_DATE                              GEO           DGUID  \
# 0      2011/2012                           Canada  2021A000011124
# 1      2012/2013                           Canada  2021A000011124
# 2      2013/2014                           Canada  2021A000011124
# 3      2014/2015                           Canada  2021A000011124
# 4      2015/2016                           Canada  2021A000011124
# ...          ...                              ...             ...
# 15211  2017/2018  Nunavut Arctic College, Nunavut             NaN
# 15212  2018/2019  Nunavut Arctic College, Nunavut             NaN
# 15213  2019/2020  Nunavut Arctic College, Nunavut             NaN
# 15214  2020/2021  Nunavut Arctic College, Nunavut             NaN
# 15215  2021/2022  Nunavut Arctic College, Nunavut             NaN
#
#               Field of study         Program type  \
# 0      Total, field of study  Total, program type
# 1      Total, field of study  Total, program type
# 2      Total, field of study  Total, program type
# 3      Total, field of study  Total, program type
# 4      Total, field of study  Total, program type
# ...                      ...                  ...
# 15211  Total, field of study  Total, program type
# 15212  Total, field of study  Total, program type
# 15213  Total, field of study  Total, program type
# 15214  Total, field of study  Total, program type
# 15215  Total, field of study  Total, program type
#
#                        Credential type          Institution type  \
# 0                          Certificate  Total, institution type
# 1                          Certificate  Total, institution type
# 2                          Certificate  Total, institution type
# 3                          Certificate  Total, institution type
# 4                          Certificate  Total, institution type
# ...                                ...                       ...
# 15211  Not applicable, credential type  Total, institution type
# 15212  Not applicable, credential type  Total, institution type
# 15213  Not applicable, credential type  Total, institution type
# 15214  Not applicable, credential type  Total, institution type
# 15215  Not applicable, credential type  Total, institution type
#
#       Registration status Status of student in Canada         Gender  ...  \
# 0       Full-time student           Canadian students  Total, gender  ...
# 1       Full-time student           Canadian students  Total, gender  ...
# 2       Full-time student           Canadian students  Total, gender  ...
# 3       Full-time student           Canadian students  Total, gender  ...
# 4       Full-time student           Canadian students  Total, gender  ...
# ...                   ...                         ...            ...  ...
# 15211   Full-time student           Canadian students  Total, gender  ...
# 15212   Full-time student           Canadian students  Total, gender  ...
# 15213   Full-time student           Canadian students  Total, gender  ...
# 15214   Full-time student           Canadian students  Total, gender  ...
# 15215   Full-time student           Canadian students  Total, gender  ...
#
#       UOM_ID  SCALAR_FACTOR SCALAR_ID       VECTOR         COORDINATE  \
# 0        223          units         0  v1438513299    1.1.1.3.1.2.2.1
# 1        223          units         0  v1438513299    1.1.1.3.1.2.2.1
# 2        223          units         0  v1438513299    1.1.1.3.1.2.2.1
# 3        223          units         0  v1438513299    1.1.1.3.1.2.2.1
# 4        223          units         0  v1438513299    1.1.1.3.1.2.2.1
# ...      ...            ...       ...          ...                ...
# 15211    223          units         0  v1445971484  258.1.1.9.1.2.2.1
# 15212    223          units         0  v1445971484  258.1.1.9.1.2.2.1
# 15213    223          units         0  v1445971484  258.1.1.9.1.2.2.1
# 15214    223          units         0  v1445971484  258.1.1.9.1.2.2.1
# 15215    223          units         0  v1445971484  258.1.1.9.1.2.2.1
#
#          VALUE  STATUS SYMBOL  TERMINATED  DECIMALS
# 0      68367.0     NaN    NaN         NaN         0
# 1      69231.0     NaN    NaN         NaN         0
# 2      74811.0     NaN    NaN         NaN         0
# 3      74370.0     NaN    NaN         NaN         0
# 4      71352.0     NaN    NaN         NaN         0
# ...        ...     ...    ...         ...       ...
# 15211     99.0     NaN    NaN         NaN         0
# 15212    117.0     NaN    NaN         NaN         0
# 15213    129.0     NaN    NaN         NaN         0
# 15214    147.0     NaN    NaN         NaN         0
# 15215    138.0     NaN    NaN         NaN         0
#
# [15216 rows x 21 columns]

# %%
print(df.columns)
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Field of study', 'Program type',
#        'Credential type', 'Institution type', 'Registration status',
#        'Status of student in Canada', 'Gender', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %% [markdown]
# drop unnecessary columns

# %%
df.drop(['DGUID', 'Field of study', 'Program type', 'Institution type', 'Gender', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'], axis=1, inplace=True)

# %%
df
# Out:
#         REF_DATE                              GEO  \
# 0      2011/2012                           Canada
# 1      2012/2013                           Canada
# 2      2013/2014                           Canada
# 3      2014/2015                           Canada
# 4      2015/2016                           Canada
# ...          ...                              ...
# 15211  2017/2018  Nunavut Arctic College, Nunavut
# 15212  2018/2019  Nunavut Arctic College, Nunavut
# 15213  2019/2020  Nunavut Arctic College, Nunavut
# 15214  2020/2021  Nunavut Arctic College, Nunavut
# 15215  2021/2022  Nunavut Arctic College, Nunavut
#
#                        Credential type Registration status  \
# 0                          Certificate   Full-time student
# 1                          Certificate   Full-time student
# 2                          Certificate   Full-time student
# 3                          Certificate   Full-time student
# 4                          Certificate   Full-time student
# ...                                ...                 ...
# 15211  Not applicable, credential type   Full-time student
# 15212  Not applicable, credential type   Full-time student
# 15213  Not applicable, credential type   Full-time student
# 15214  Not applicable, credential type   Full-time student
# 15215  Not applicable, credential type   Full-time student
#
#       Status of student in Canada    VALUE
# 0               Canadian students  68367.0
# 1               Canadian students  69231.0
# 2               Canadian students  74811.0
# 3               Canadian students  74370.0
# 4               Canadian students  71352.0
# ...                           ...      ...
# 15211           Canadian students     99.0
# 15212           Canadian students    117.0
# 15213           Canadian students    129.0
# 15214           Canadian students    147.0
# 15215           Canadian students    138.0
#
# [15216 rows x 6 columns]

# %% [markdown]
# Rename columns so it is clearer to read - same processing as the international/domestic split

# %%
# rename columns
df.rename(columns={"REF_DATE": "FY Start","GEO": "School/Locality", "Status of student in Canada": "Status", "VALUE": "Enrolment"}, inplace=True)

# %%
df["FY Start"] = df["FY Start"].apply(lambda x: int(x[:4]))

# %% [markdown]
# split up the provincial data from individual schools

# %%
# List of provinces and territories in Canada
canadian_provinces_territories = [
    "Alberta", "British Columbia", "Manitoba", "New Brunswick", "Newfoundland and Labrador",
    "Nova Scotia", "Ontario", "Prince Edward Island", "Quebec", "Saskatchewan",
    "Northwest Territories", "Nunavut", "Yukon", "Canada"
]

# Convert the list to a set for fast exact matching
province_set = set(canadian_provinces_territories)

# Create a mask for exact matches with Canada or any province/territory
exact_match_mask = df['School/Locality'].isin(province_set)

# Create the Canada & Provinces DataFrame (exact matches)
canada_df = df[exact_match_mask]

# For rows that do not match exactly, extract the college/university name before the last comma
# We will create a mask where School/Locality does not match any province or Canada
schools_df = df[~exact_match_mask]

# Correctly extract the institution name (everything before the last comma)
# Ensure you use rsplit correctly, specifying the delimiter (comma) and maxsplit=1
schools_df['Institution Name'] = schools_df['School/Locality'].str.rsplit(',', n=1).str[0]

# Now, `canada_df` contains rows where School/Locality is exactly a province or territory, and
# `schools_df` contains rows with college/university names (before the last comma)
# If you want to merge both DataFrames back into a single one:
schools_df.drop(columns=['School/Locality'], inplace=True)

# Display the results
print(f"Number of rows in canada_df: {len(canada_df)}")
print(f"Number of rows in colleges_universities_df: {len(schools_df)}")
# Out:
# Number of rows in canada_df: 1313
# Number of rows in colleges_universities_df: 13903
# /var/folders/jj/bww8jnqd2lg73nm4k1z5kbmc0000gn/T/ipykernel_3573/2067161562.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_df['Institution Name'] = schools_df['School/Locality'].str.rsplit(',', n=1).str[0]
# /var/folders/jj/bww8jnqd2lg73nm4k1z5kbmc0000gn/T/ipykernel_3573/2067161562.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_df.drop(columns=['School/Locality'], inplace=True)

# %%
# move Institution Name to the front of the DataFrame
cols = schools_df.columns.tolist()
cols = cols[-1:] + cols[:-1]
schools_df = schools_df[cols]

# %%
schools_df.sample(10)
# Out:
#                                Institution Name  FY Start  \
# 10599                      Athabasca University      2015
# 5154     Collège Centennal / Centennial College      2014
# 3192            Université du Québec à Rimouski      2019
# 6783                      University of Toronto      2020
# 10821                  University of Lethbridge      2016
# 10724                     University of Calgary      2015
# 12886  British Columbia Institute of Technology      2015
# 5220                      Collège André-Grasset      2013
# 10391                      Great Plains College      2017
# 6962                     University of Waterloo      2021
#
#                         Credential type Registration status  \
# 10599                           Diploma   Full-time student
# 5154                            Diploma   Full-time student
# 3192    Not applicable, credential type   Full-time student
# 6783                        Certificate   Full-time student
# 10821                       Certificate   Full-time student
# 10724   Not applicable, credential type   Full-time student
# 12886                           Diploma   Full-time student
# 5220                            Diploma   Full-time student
# 10391   Not applicable, credential type   Full-time student
# 6962   Degree (includes applied degree)   Full-time student
#
#                        Status  Enrolment
# 10599  International students        3.0
# 5154        Canadian students       75.0
# 3192        Canadian students        6.0
# 6783        Canadian students        9.0
# 10821       Canadian students        9.0
# 10724  International students      309.0
# 12886       Canadian students     4977.0
# 5220        Canadian students     1212.0
# 10391       Canadian students       12.0
# 6962   International students     8619.0

# %%
canada_df.sample(10)
# Out:
#        FY Start School/Locality  \
# 10430      2012         Alberta
# 9152       2016        Manitoba
# 50         2017          Canada
# 6091       2020         Ontario
# 55         2011          Canada
# 10479      2017         Alberta
# 67         2012          Canada
# 9163       2016        Manitoba
# 9086       2016        Manitoba
# 705        2020     Nova Scotia
#
#                                          Credential type Registration status  \
# 10430                                            Diploma   Full-time student
# 9152   Other type of credential associated with a pro...   Full-time student
# 50                      Degree (includes applied degree)   Full-time student
# 6091   Other type of credential associated with a pro...   Full-time student
# 55                      Degree (includes applied degree)   Full-time student
# 10479                    Not applicable, credential type   Full-time student
# 67                                      Associate degree   Full-time student
# 9163   Other type of credential associated with a pro...   Full-time student
# 9086                                         Certificate   Full-time student
# 705                     Degree (includes applied degree)   Full-time student
#
#                        Status  Enrolment
# 10430  International students     2517.0
# 9152        Canadian students      948.0
# 50          Canadian students   839289.0
# 6091        Canadian students     1422.0
# 55     International students    86757.0
# 10479  International students     1608.0
# 67          Canadian students     9510.0
# 9163   International students       93.0
# 9086   International students      627.0
# 705         Canadian students    26622.0

# %%
# rename the School/Locality column to Province in canada_df
canada_df.rename(columns={"School/Locality": "Province"}, inplace=True)
# Out:
# /var/folders/jj/bww8jnqd2lg73nm4k1z5kbmc0000gn/T/ipykernel_3573/3974821115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   canada_df.rename(columns={"School/Locality": "Province"}, inplace=True)

# %%
canada_df.sample(5)
# Out:
#        FY Start               Province  \
# 12356      2021       British Columbia
# 15074      2015  Northwest Territories
# 79         2013                 Canada
# 6103       2021                Ontario
# 9084       2014               Manitoba
#
#                                          Credential type Registration status  \
# 12356                   Degree (includes applied degree)   Full-time student
# 15074                    Not applicable, credential type   Full-time student
# 79                                      Associate degree   Full-time student
# 6103   Other type of credential associated with a pro...   Full-time student
# 9084                                         Certificate   Full-time student
#
#                        Status  Enrolment
# 12356  International students    25836.0
# 15074       Canadian students        3.0
# 79     International students      828.0
# 6103   International students      291.0
# 9084   International students      261.0
